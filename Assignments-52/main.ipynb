# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# Mnist - MLP

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
  loss='sparse_categorical_crossentropy',
  metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 795us/step - loss: 0.2992 - accuracy: 0.9130 - val_loss: 0.1429 - val_accuracy: 0.9582
# Epoch 2/5
# 1875/1875 [==============================] - 1s 769us/step - loss: 0.1446 - accuracy: 0.9575 - val_loss: 0.1024 - val_accuracy: 0.9697
# Epoch 3/5
# 1875/1875 [==============================] - 1s 798us/step - loss: 0.1086 - accuracy: 0.9681 - val_loss: 0.0911 - val_accuracy: 0.9713
# Epoch 4/5
# 1875/1875 [==============================] - 1s 768us/step - loss: 0.0871 - accuracy: 0.9724 - val_loss: 0.0770 - val_accuracy: 0.9764
# Epoch 5/5
# 1875/1875 [==============================] - 1s 773us/step - loss: 0.0750 - accuracy: 0.9762 - val_loss: 0.0692 - val_accuracy: 0.9793

# %%
# Plot loss
plt.figure(figsize=(10, 7))
plt.plot(history.history['loss'], label='Loss - Train', color='red')
plt.plot(history.history['val_loss'], label='Loss - Test', color='blue')
plt.title('Loss vs. Epochs (MNIST - MLP)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# Plot accuracy
plt.figure(figsize=(10, 7))
plt.plot(history.history['accuracy'], label='Accuracy - Train', color='green')
plt.plot(history.history['val_accuracy'], label='Accuracy - Test', color='purple')
plt.title('Accuracy vs. Epochs (MNIST - MLP)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# Fashion_Mnist - MLP

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(x_train_fashion, y_train_fashion), (x_test_fashion, y_test_fashion) = fashion_mnist.load_data()
x_train_fashion, x_test_fashion = x_train_fashion / 255.0, x_test_fashion / 255.0
# Out:
# ...
# 4422102/4422102 [==============================] - 34s 8us/step

# %%
model_fashion = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
    ])

# %%
model_fashion.compile(optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])
history_fashion = model_fashion.fit(x_train_fashion, y_train_fashion, epochs=5, validation_data=(x_test_fashion, y_test_fashion))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 805us/step - loss: 0.5276 - accuracy: 0.8128 - val_loss: 0.4366 - val_accuracy: 0.8462
# Epoch 2/5
# 1875/1875 [==============================] - 1s 780us/step - loss: 0.4017 - accuracy: 0.8547 - val_loss: 0.3860 - val_accuracy: 0.8602
# Epoch 3/5
# 1875/1875 [==============================] - 1s 783us/step - loss: 0.3660 - accuracy: 0.8662 - val_loss: 0.3895 - val_accuracy: 0.8540
# Epoch 4/5
# 1875/1875 [==============================] - 1s 783us/step - loss: 0.3456 - accuracy: 0.8733 - val_loss: 0.3765 - val_accuracy: 0.8563
# Epoch 5/5
# 1875/1875 [==============================] - 1s 774us/step - loss: 0.3301 - accuracy: 0.8783 - val_loss: 0.3614 - val_accuracy: 0.8715

# %%
# Plot loss
plt.figure(figsize=(10, 7))
plt.plot(history_fashion.history['loss'], label='Loss - Train', color='red')
plt.plot(history_fashion.history['val_loss'], label='Loss - Test', color='blue')
plt.title('Loss vs. Epochs (Fashion MNIST - MLP)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# Plot accuracy
plt.figure(figsize=(10, 7))
plt.plot(history_fashion.history['accuracy'], label='Accuracy - Train', color='green')
plt.plot(history_fashion.history['val_accuracy'], label='Accuracy - Test', color='purple')
plt.title('Accuracy vs. Epochs (Fashion MNIST - MLP)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# Cifar10 - MLP

# %%
cifar10 = tf.keras.datasets.cifar10

(x_train_cifar10, y_train_cifar10), (x_test_cifar10, y_test_cifar10) = cifar10.load_data()
x_train_cifar10, x_test_cifar10 = x_train_cifar10 / 255.0, x_test_cifar10 / 255.0

# %%
model_cifar10 = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
    ])

# %%
model_cifar10.compile(optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])
history_cifar10 = model_cifar10.fit(x_train_cifar10, y_train_cifar10, epochs=5, validation_data=(x_test_cifar10, y_test_cifar10))
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 2.0121 - accuracy: 0.2520 - val_loss: 1.9195 - val_accuracy: 0.2978
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.9327 - accuracy: 0.2817 - val_loss: 1.8299 - val_accuracy: 0.3393
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.9101 - accuracy: 0.2908 - val_loss: 1.8259 - val_accuracy: 0.3287
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.9008 - accuracy: 0.2983 - val_loss: 1.8357 - val_accuracy: 0.3416
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.8962 - accuracy: 0.2997 - val_loss: 1.8180 - val_accuracy: 0.3433

# %%
# Plot loss
plt.figure(figsize=(10, 7))
plt.plot(history_cifar10.history['loss'], label='Loss - Train', color='red')
plt.plot(history_cifar10.history['val_loss'], label='Loss - Test', color='blue')
plt.title('Loss vs. Epochs (CIFAR10 - MLP)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# Plot accuracy
plt.figure(figsize=(10, 7))
plt.plot(history_cifar10.history['accuracy'], label='Accuracy - Train', color='green')
plt.plot(history_cifar10.history['val_accuracy'], label='Accuracy - Test', color='purple')
plt.title('Accuracy vs. Epochs (CIFAR10 - MLP)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# Cifar100 - MLP

# %%
cifar100 = tf.keras.datasets.cifar100
(x_train_cifar100, y_train_cifar100), (x_test_cifar100, y_test_cifar100) = cifar100.load_data()
x_train_cifar100, x_test_cifar100 = x_train_cifar100 / 255.0, x_test_cifar100 / 255.0
# Out:
# ...
# 169001437/169001437 [==============================] - 1192s 7us/step

# %%
model_cifar100 = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(100, activation='softmax')
    ])

# %%
model_cifar100.compile(optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])
history_cifar100 = model_cifar100.fit(x_train_cifar100, y_train_cifar100, epochs=5, validation_data=(x_test_cifar100, y_test_cifar100))
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 4.5196 - accuracy: 0.0155 - val_loss: 4.4436 - val_accuracy: 0.0209
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 4.4646 - accuracy: 0.0172 - val_loss: 4.4287 - val_accuracy: 0.0232
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 4.4516 - accuracy: 0.0188 - val_loss: 4.4166 - val_accuracy: 0.0226
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 4.4466 - accuracy: 0.0204 - val_loss: 4.3995 - val_accuracy: 0.0223
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 4.4441 - accuracy: 0.0192 - val_loss: 4.3938 - val_accuracy: 0.0226

# %%
# Plot loss
plt.figure(figsize=(10, 7))
plt.plot(history_cifar100.history['loss'], label='Loss - Train', color='red')
plt.plot(history_cifar100.history['val_loss'], label='Loss - Test', color='blue')
plt.title('Loss vs. Epochs (CIFAR100 - MLP)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# Plot accuracy
plt.figure(figsize=(10, 7))
plt.plot(history_cifar100.history['accuracy'], label='Accuracy - Train', color='green')
plt.plot(history_cifar100.history['val_accuracy'], label='Accuracy - Test', color='purple')
plt.title('Accuracy vs. Epochs (CIFAR100 - MLP)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# Mnist - DeepLearning

# %%
mnist_deep = tf.keras.datasets.mnist
(x_train_deep, y_train_deep),(x_test_deep, y_test_deep) = mnist_deep.load_data()
x_train_deep, x_test_deep = x_train_deep / 255.0, x_test_deep / 255.0

# %%
model_deep = tf.keras.models.Sequential([
    
    #deep learning
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Flatten(),

    #machine learning
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
    ])

# %%
model_deep.compile(optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])
history_deep = model_deep.fit(x_train_deep, y_train_deep, epochs=5, validation_data=(x_test_deep, y_test_deep))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1527 - accuracy: 0.9531 - val_loss: 0.0396 - val_accuracy: 0.9880
# Epoch 2/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0482 - accuracy: 0.9854 - val_loss: 0.0331 - val_accuracy: 0.9891
# Epoch 3/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0354 - accuracy: 0.9893 - val_loss: 0.0285 - val_accuracy: 0.9909
# Epoch 4/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0273 - accuracy: 0.9916 - val_loss: 0.0297 - val_accuracy: 0.9916
# Epoch 5/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0211 - accuracy: 0.9936 - val_loss: 0.0273 - val_accuracy: 0.9926

# %%
# Plot loss
plt.figure(figsize=(10, 7))
plt.plot(history_deep.history['loss'], label='Loss - Train', color='red')
plt.plot(history_deep.history['val_loss'], label='Loss - Test', color='blue')
plt.title('Loss vs. Epochs (MNIST - CNN)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# Plot accuracy
plt.figure(figsize=(10, 7))
plt.plot(history_deep.history['accuracy'], label='Accuracy - Train', color='green')
plt.plot(history_deep.history['val_accuracy'], label='Accuracy - Test', color='purple')
plt.title('Accuracy vs. Epochs (MNIST - CNN)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# Fashion_Mnist - DeepLearning

# %%
fashion_mnist_deep = tf.keras.datasets.fashion_mnist
(x_train_fashion_deep, y_train_fashion_deep), (x_test_fashion_deep, y_test_fashion_deep) = fashion_mnist_deep.load_data()
x_train_fashion_deep, x_test_fashion_deep = x_train_fashion_deep / 255.0, x_test_fashion_deep / 255.0

# %%
model_fashion_deep = tf.keras.models.Sequential([
    
    #deep learning
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Flatten(),

    #machine learning
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
    ])

# %%
model_fashion_deep.compile(optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])
history_fashion_deep = model_fashion_deep.fit(x_train_fashion_deep, y_train_fashion_deep, epochs=5, validation_data=(x_test_fashion_deep, y_test_fashion_deep))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.5086 - accuracy: 0.8125 - val_loss: 0.3714 - val_accuracy: 0.8619
# Epoch 2/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3268 - accuracy: 0.8817 - val_loss: 0.3022 - val_accuracy: 0.8909
# Epoch 3/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2822 - accuracy: 0.8968 - val_loss: 0.3161 - val_accuracy: 0.8805
# Epoch 4/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2511 - accuracy: 0.9082 - val_loss: 0.2745 - val_accuracy: 0.9007
# Epoch 5/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2279 - accuracy: 0.9155 - val_loss: 0.2693 - val_accuracy: 0.9017

# %%
# Plot loss
plt.figure(figsize=(10, 7))
plt.plot(history_fashion_deep.history['loss'], label='Loss - Train', color='red')
plt.plot(history_fashion_deep.history['val_loss'], label='Loss - Test', color='blue')
plt.title('Loss vs. Epochs (Fashion MNIST - CNN)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# Plot accuracy
plt.figure(figsize=(10, 7))
plt.plot(history_fashion_deep.history['accuracy'], label='Accuracy - Train', color='green')
plt.plot(history_fashion_deep.history['val_accuracy'], label='Accuracy - Test', color='purple')
plt.title('Accuracy vs. Epochs (Fashion MNIST - CNN)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# Cifar10 - DeepLearning

# %%
cifar10_deep = tf.keras.datasets.cifar10
(x_train_cifar10_deep, y_train_cifar10_deep), (x_test_cifar10_deep, y_test_cifar10_deep) = cifar10_deep.load_data()
x_train_cifar10_deep, x_test_cifar10_deep = x_train_cifar10_deep / 255.0, x_test_cifar10_deep / 255.0

# %%
model_cifar10_deep = tf.keras.models.Sequential([
    
    #deep learning
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Flatten(),

    #machine learning
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
    ])

# %%
model_cifar10_deep.compile(optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])
history_cifar10_deep = model_cifar10_deep.fit(x_train_cifar10_deep, y_train_cifar10_deep, epochs=5, validation_data=(x_test_cifar10_deep, y_test_cifar10_deep))
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 16s 10ms/step - loss: 1.5485 - accuracy: 0.4324 - val_loss: 1.2429 - val_accuracy: 0.5542
# Epoch 2/5
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.1706 - accuracy: 0.5834 - val_loss: 1.0811 - val_accuracy: 0.6142
# Epoch 3/5
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.0244 - accuracy: 0.6367 - val_loss: 0.9628 - val_accuracy: 0.6641
# Epoch 4/5
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.9265 - accuracy: 0.6757 - val_loss: 0.9017 - val_accuracy: 0.6827
# Epoch 5/5
# 1563/1563 [==============================] - 16s 10ms/step - loss: 0.8540 - accuracy: 0.6996 - val_loss: 0.9202 - val_accuracy: 0.6801

# %%
# Plot loss
plt.figure(figsize=(10, 7))
plt.plot(history_cifar10_deep.history['loss'], label='Loss - Train', color='red')
plt.plot(history_cifar10_deep.history['val_loss'], label='Loss - Test', color='blue')
plt.title('Loss vs. Epochs (CIFAR10 - CNN)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# Plot accuracy
plt.figure(figsize=(10, 7))
plt.plot(history_cifar10_deep.history['accuracy'], label='Accuracy - Train', color='green')
plt.plot(history_cifar10_deep.history['val_accuracy'], label='Accuracy - Test', color='purple')
plt.title('Accuracy vs. Epochs (CIFAR10 - CNN)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# Cifar100 - DeepLearning

# %%
cifar100_deep = tf.keras.datasets.cifar100
(x_train_cifar100_deep, y_train_cifar100_deep), (x_test_cifar100_deep, y_test_cifar100_deep) = cifar100_deep.load_data()
x_train_cifar100_deep, x_test_cifar100_deep = x_train_cifar100_deep / 255.0, x_test_cifar100_deep / 255.0

# %%
model_cifar100_deep = tf.keras.models.Sequential([
    
    #deep learning
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Flatten(),

    #machine learning
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(100, activation='softmax')
    ])

# %%
model_cifar100_deep.compile(optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])
history_cifar100_deep = model_cifar100_deep.fit(x_train_cifar100_deep, y_train_cifar100_deep, epochs=5, validation_data=(x_test_cifar100_deep, y_test_cifar100_deep))
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 16s 10ms/step - loss: 3.9872 - accuracy: 0.0874 - val_loss: 3.5266 - val_accuracy: 0.1639
# Epoch 2/5
# 1563/1563 [==============================] - 15s 10ms/step - loss: 3.3610 - accuracy: 0.1898 - val_loss: 3.0957 - val_accuracy: 0.2449
# Epoch 3/5
# 1563/1563 [==============================] - 16s 10ms/step - loss: 3.0772 - accuracy: 0.2396 - val_loss: 2.8968 - val_accuracy: 0.2828
# Epoch 4/5
# 1563/1563 [==============================] - 16s 10ms/step - loss: 2.8995 - accuracy: 0.2724 - val_loss: 2.8571 - val_accuracy: 0.2899
# Epoch 5/5
# 1563/1563 [==============================] - 16s 10ms/step - loss: 2.7736 - accuracy: 0.2989 - val_loss: 2.7296 - val_accuracy: 0.3197

# %%
# Plot loss
plt.figure(figsize=(10, 7))
plt.plot(history_cifar100_deep.history['loss'], label='Loss - Train', color='red')
plt.plot(history_cifar100_deep.history['val_loss'], label='Loss - Test', color='blue')
plt.title('Loss vs. Epochs (CIFAR100 - CNN)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# Plot accuracy
plt.figure(figsize=(10, 7))
plt.plot(history_cifar100_deep.history['accuracy'], label='Accuracy - Train', color='green')
plt.plot(history_cifar100_deep.history['val_accuracy'], label='Accuracy - Test', color='purple')
plt.title('Accuracy vs. Epochs (CIFAR100 - CNN)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()
